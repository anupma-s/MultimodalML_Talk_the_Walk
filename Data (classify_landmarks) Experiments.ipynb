# %%
import json
import os
import numpy as np
import pickle

# %%
x = pickle.load(open('./data.pkl', 'rb'))

# %%
x

# %%
x.__dict__.keys()
# Out:
# dict_keys(['num_tokens', 'textfeatures', 'feature_loaders', 'textrecog_dict', 'data', 'map'])

# %%
x.map.__dict__.keys()
# Out:
# dict_keys(['landmarks', 'coord_to_landmarks', 'landmark_dict', 'include_empty_corners', 'data_dir'])

# %%
x.map.coord_to_landmarks
# Out:
# {'eastvillage': [[[3], [3], [], [3], [8], [3], [3], [8], [2], [3], [3], []],
#   [[], [], [3], [1], [3], [4], [2], [3], [2], [3, 3], [8], [8]],
#   [[2], [2], [2, 2], [1], [3], [3], [2, 3], [], [3], [3, 3], [2], []],
#   [[1], [], [], [], [], [], [], [], [6], [3], [2], [2]],
#   [[], [], [], [2, 2], [4], [], [], [3], [], [3], [3], [8]],
#   [[2], [3], [2], [3], [], [2, 2], [], [], [], [3], [], [6]],
#   [[], [2], [], [3], [3], [], [], [3], [], [3], [], [6]],
#   [[3], [8], [], [], [3], [], [], [], [3], [2], [], []],
#   [[], [], [3], [], [], [], [2], [2], [], [2], [2], [2]],
#   [[], [], [], [4], [2], [3], [], [], [], [], [8], []]],
#  'fidi': [[[], [], [], [], [], [], [5], [5], [], []],
#   [[], [4], [4], [4], [], [2, 4], [4, 2], [4], [5], [4]],
#   [[], [], [3], [], [], [1], [4, 2], [2], [], [2]],
#   [[5], [], [], [], [], [], [], [5], [1, 1], [2]],
#   [[], [5], [], [], [], [], [], [], [], [3]],
#   [[5], [5], [8], [], [], [], [4], [4], [5], [2]],
# ...

# %% [markdown]
# ## fastText features

# %%
data_fasttext = pickle.load(open('./data_fasttext.pkl', 'rb'))

# %%
len(data_fasttext[0][1])
# Out:
# 300
